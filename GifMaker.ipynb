# %%
# %matplotlib inline
import matplotlib as mpl
import nuSQUIDSpy as nsq
import matplotlib.pyplot as plt

import nuSQUIDSTools
import numpy as np
import time as t

# %%
import glob
from PIL import Image 
#gif making module

# %%
def OscGif(framefolder,frameending,savefolder,gifname,dur=1000):
    '''
    
    Inputs (type: str):
    
    framefolder: folder where the frames are stored e.g. "Osc_Param_Test_Plots/PlotSeries2/Th14"
    frameending: ending name of the frames to be specified e.g. "*_Th14_sneu_mu_ini.png"
    
    savefolder: folder where gif will be saved "Osc_Param_Test_Gifs"
    gifname: name of gif output e.eg. "Plotseries2_th14_sneu_mu_ini.gif"
    
    dur: frame duration in ms, default 1000ms
    
    '''
    
    frameloc = framefolder+"/"+frameending #frame location string
    save = savefolder+"/"+gifname #save gif string
    
    frames = []
    imgs = sorted(glob.glob(frameloc)) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save(save, format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=dur, loop=0)

# %% [markdown]
# ## New Nodes

# %%
savefolder_e = "Osc_Param_Test_Gifs/NewNodes/nue"
savefolder_mu = "Osc_Param_Test_Gifs/NewNodes/numu"

# %%
newnodegifs = False

# %%
if newnodegifs == True:

    # mu new node gif single theta
    #series 1
    framefol = "Osc_Param_Test_Plots/PlotSeries1/Theta23"
    frameend, frameantiend = "*_th23_neu_mu_ini_newnodes.png", "*_th23_antineu_mu_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th23_neu_mu.gif", "newnode_th23_antineu_mu.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    framefol = "Osc_Param_Test_Plots/PlotSeries1/m23"
    frameend, frameantiend = "*_m23_neu_mu_ini_newnodes.png", "*_m23_antineu_mu_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_m23_neu_mu.gif", "newnode_m23_antineu_mu.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    framefol = "Osc_Param_Test_Plots/PlotSeries1/ThM23"
    frameend, frameantiend = "*_Th23_neu_mu_ini_newnodes.png", "*_Th23_antineu_mu_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th23m23_neu_mu.gif", "newnode_th23m23_antineu_mu.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    #series 2
    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th14"
    frameend, frameantiend = "*_Th14_sneu_mu_ini_newnodes.png", "*_Th14_antisneu_mu_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th14_neu_mu.gif", "newnode_th14_antineu_mu.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th24"
    frameend, frameantiend = "*_Th24_sneu_mu_ini_newnodes.png", "*_Th24_antisneu_mu_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th24_neu_mu.gif", "newnode_th24_antineu_mu.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th34"
    frameend, frameantiend = "*_Th34_sneu_mu_ini_newnodes.png", "*_Th34_antisneu_mu_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th34_neu_mu.gif", "newnode_th34_antineu_mu.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)


    # e new node gif single theta

    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th14"
    frameend, frameantiend = "*_Th14_sneu_e_ini_newnodes.png", "*_Th14_antisneu_e_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th14_neu_e.gif", "newnode_th14_antineu_e.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th24"
    frameend, frameantiend = "*_Th24_sneu_e_ini_newnodes.png", "*_Th24_antisneu_e_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th24_neu_e.gif", "newnode_th24_antineu_e.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th34"
    frameend, frameantiend = "*_Th34_sneu_e_ini_newnodes.png", "*_Th34_antisneu_e_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th34_neu_e.gif", "newnode_th34_antineu_e.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

# %%
if newnodegifs == True:
    # mu new node gif multi theta
    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th_14_24"
    frameend, frameantiend = "*_Th14_Th24_sneu_mu_ini_newnodes.png", "*_Th14_Th24_antisneu_mu_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th14th24_neu_mu.gif", "newnode_th14th24_antineu_mu.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th_24_34"
    frameend, frameantiend = "*_Th24_Th34_sneu_mu_ini_newnodes.png", "*_Th24_Th34_antisneu_mu_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th24th34_neu_mu.gif", "newnode_th24th34_antineu_mu.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th_14_34"
    frameend, frameantiend = "*_Th14_Th34_sneu_mu_ini_newnodes.png", "*_Th14_Th34_antisneu_mu_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th14th34_neu_mu.gif", "newnode_th14th34_antineu_mu.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th_14_24_34"
    frameend, frameantiend = "*_Th14_24_Th34_sneu_mu_ini_newnodes.png", "*_Th14_24_Th34_antisneu_mu_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th14th24th34_neu_mu.gif", "newnode_th14th24th34_antineu_mu.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    # e new node gif multi theta
    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th_14_24"
    frameend, frameantiend = "*_Th14_Th24_sneu_e_ini_newnodes.png", "*_Th14_Th24_antisneu_e_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th14th24_neu_e.gif", "newnode_th14th24_antineu_e.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th_24_34"
    frameend, frameantiend = "*_Th24_Th34_sneu_e_ini_newnodes.png", "*_Th24_Th34_antisneu_e_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th24th34_neu_e.gif", "newnode_th24th34_antineu_e.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th_14_34"
    frameend, frameantiend = "*_Th14_Th34_sneu_e_ini_newnodes.png", "*_Th14_Th34_antisneu_e_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th14th34_neu_e.gif", "newnode_th14th34_antineu_e.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

    framefol = "Osc_Param_Test_Plots/PlotSeries2/Th_14_24_34"
    frameend, frameantiend = "*_Th14_24_Th34_sneu_e_ini_newnodes.png", "*_Th14_24_Th34_antisneu_e_ini_newnodes.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "newnode_th14th24th34_neu_e.gif", "newnode_th14th24th34_antineu_e.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder_mu,gifname)
    OscGif(framefol,frameantiend,savefolder_mu,gifantiname)

# %% [markdown]
# # Plotseries 1
# ## $\Theta_{23}$

# %%
plotseries1gifs = False
plotseries2gifs = False

# %%
if plotseries1gifs == True:

    #neugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries1/Theta23/*th23_neu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        new_frame = new_frame.resize((804,559))
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries1_th23_neu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

    #antineugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries1/Theta23/*th23_antineu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        new_frame = new_frame.resize((804,559))
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries1_th23_antineu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

# %% [markdown]
# ## $\Delta m_{23}^2$

# %%
if plotseries1gifs == True:

    #neugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries1/m23/*m23_neu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries1_m23_neu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

    #antineugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries1/m23/*m23_antineu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries1_m23_antineu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

# %% [markdown]
# ## Interference $\Delta m_{23}^2, \Theta_{23}$

# %%
if plotseries1gifs == True:

    #neugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries1/ThM23/*Th23_neu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries1_m23_th23_neu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

    #antineugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries1/ThM23/*Th23_antineu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries1_m23_th23_antineu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

# %% [markdown]
# # Plotseries 2

# %% [markdown]
# ## $\Theta_{14}, \Theta_{24}, \Theta_{34}$

# %%
if plotseries2gifs == True:

    #neugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th14/*_Th14_sneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th14_sneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

    #antineugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th14/*_Th14_antisneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th14_antisneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

# %%
if plotseries2gifs == True:

    #neugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th24/*_Th24_sneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th24_sneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

    #antineugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th24/*_Th24_antisneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th24_antisneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

# %%
if plotseries2gifs == True:

    #neugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th34/*_Th34_sneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th34_sneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

    #antineugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th34/*_Th34_antisneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th34_antisneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

# %% [markdown]
# ## $\Theta_{ij}$ interference

# %%
if plotseries2gifs == True:

    #neugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th_14_24/*_Th14_Th24_sneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th_14_24_sneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

    #antineugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th_14_24/*_Th14_Th24_antisneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th_14_24_antisneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

# %%
if plotseries2gifs == True:

    #neugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th_14_34/*_Th14_Th34_sneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th_14_34_sneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

    #antineugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th_14_34/*_Th14_Th34_antisneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th_14_34_antisneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

# %%
if plotseries2gifs == True:

    #neugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th_24_34/*_Th24_Th34_sneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th_24_34_sneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

    #antineugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th_24_34/*_Th24_Th34_antisneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th_24_34_antisneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

# %%
if plotseries2gifs == True:

    #neugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th_14_24_34/*_Th14_24_Th34_sneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th_14_24_34_sneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

    #antineugif
    frames = []
    imgs = sorted(glob.glob("Osc_Param_Test_Plots/PlotSeries2/Th_14_24_34/*_Th14_24_Th34_antisneu_mu_ini.png")) #works
    for i in imgs:
        new_frame = Image.open(i)
        temp = Image.open(imgs[0]) 
        new_frame = new_frame.resize(temp.size) # resizes all frames to first image size
        frames.append(new_frame)

    # Save into a GIF file that loops forever
    frames[0].save('Osc_Param_Test_Gifs/Plotseries2_th_14_24_34_antisneu_mu_ini.gif', format='GIF',
                   append_images=frames[1:],
                   save_all=True,
                   duration=1000, loop=0)

# %% [markdown]
# ## Flux difference oscgrams

# %%
fluxdiffplotflag = False

# %%
if fluxdiffplotflag == True:
    savefolder = "Osc_Param_Test_Gifs/FluxDiff"
    framefol = "Osc_Param_Test_Plots/SMtoSterileDiff"
    frameend, frameantiend = "*_th24_neu_mu.png", "*_th24_antineu_mu.png" #ending for neutrino and antineutrino
    gifname,gifantiname = "fluxdiff_th24_neu_mu.gif", "fluxdiff_th24_antineu_mu.gif" #neutrino, antineutrino gif name
    OscGif(framefol,frameend,savefolder,gifname,2000)
    OscGif(framefol,frameantiend,savefolder,gifantiname,2000)

# %%
manualsmoothing = False

# %%
#14 24
if manualsmoothing == True:
    savefolder = "Osc_Param_Test_Gifs/Smoothing"
    framefolder = "Osc_Param_Test_Plots/Smoothing"
    frameend, frameantiend, frameratio = ("*_th24v1424_smoothed_prob_diff_mu.png", 
                                          "*_th24v1424_smoothed_prob_diff_antimu.png", 
                                          "*_th24v1424_smoothed_prob_ratio_muanti.png")
    gifname, gifantiname, gifratio = "th1424_smoothed_mu_osc.gif", "th1424_smoothed_antimu_osc.gif", "th1424_smoothed_ratio_osc.gif"
    OscGif(framefolder,frameend,savefolder,gifname,1500)
    OscGif(framefolder,frameantiend,savefolder,gifantiname,1500)
    OscGif(framefolder,frameratio,savefolder,gifratio,1500)
#24 34    
if manualsmoothing == True:
    savefolder = "Osc_Param_Test_Gifs/Smoothing"
    framefolder = "Osc_Param_Test_Plots/Smoothing"
    frameend, frameantiend, frameratio = ("*_th24v2434_smoothed_prob_diff_mu.png", 
                                          "*_th24v2434_smoothed_prob_diff_antimu.png", 
                                          "*_th24v2434_smoothed_prob_ratio_muanti.png")    
    gifname, gifantiname, gifratio = "th2434_smoothed_mu_osc.gif", "th2434_smoothed_antimu_osc.gif", "th2434_smoothed_ratio_osc.gif"
    OscGif(framefolder,frameend,savefolder,gifname,1500)
    OscGif(framefolder,frameantiend,savefolder,gifantiname,1500)
    OscGif(framefolder,frameratio,savefolder,gifratio,1500)

# %% [markdown]
# ## Improved smooth

# %%
#24
impsmoooth = False
if impsmoooth == True:
    savefolder = "Osc_Param_Test_Gifs/Smoothing"
    framefolder = "Osc_Param_Test_Plots/Smoothing/Improved"
    SMend, end24, end2434 = ("*_SM_smoothed_osc_ratio_mu.png",
                             "*_th24_smoothed_osc_ratio_mu.png",
                             "*_th2434_smoothed_osc_ratio_mu.png")
    gifname, gifantiname, gifratio = "improved_SM_ratio.gif", "improved_th24_ratio.gif", "improved_th2434_ratio.gif"
    OscGif(framefolder,SMend,savefolder,gifname,1500)
    OscGif(framefolder,end24,savefolder,gifantiname,1500)
    OscGif(framefolder,end2434,savefolder,gifratio,1500)
    
    savefolder = "Osc_Param_Test_Gifs/Smoothing"
    framefolder = "Osc_Param_Test_Plots/Smoothing/Improved"
    end24, end2434 = ("*_th24_smoothed_osc_diff_mu.png",
                             "*_th2434_smoothed_osc_diff_mu.png")
    gifname, gifantiname, gifratio = "improved_SM_diff.gif", "improved_th24_diff.gif", "improved_th2434_diff.gif"
    OscGif(framefolder,end24,savefolder,gifantiname,1500)
    OscGif(framefolder,end2434,savefolder,gifratio,1500)
